# %%
# Import modules
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read CSV
census_csv = "Energy Census and Economic Data US 2010-2014.csv"
census_df = pd.read_csv(census_csv)

atlantic_csv = "atlantic.csv"
atlantic_df = pd.read_csv(atlantic_csv)

# %%
# Census dataset
census_df.head()
# Out:
#   StateCodes       State  Region  Division  Coast  Great Lakes  TotalC2010  \
# 0         AL     Alabama     3.0       6.0    1.0          0.0     1931522
# 1         AK      Alaska     4.0       9.0    1.0          0.0      653221
# 2         AZ     Arizona     4.0       8.0    0.0          0.0     1383531
# 3         AR    Arkansas     3.0       7.0    0.0          0.0     1120632
# 4         CA  California     4.0       9.0    1.0          0.0     7760629
#
#    TotalC2011  TotalC2012  TotalC2013  ...  RINTERNATIONALMIG2013  \
# 0     1905207     1879716     1919365  ...               1.165832
# 1      653637      649341      621107  ...               3.203618
# 2     1424944     1395839     1414383  ...               1.090035
# 3     1122544     1067642     1096438  ...               2.141877
# 4     7777115     7564063     7665241  ...               4.207353
#
#    RINTERNATIONALMIG2014  RDOMESTICMIG2011  RDOMESTICMIG2012  \
# ...

# %%
# Filter desired states

# Create mask for desired states
df_filter = census_df['StateCodes'].apply(lambda state: state in ['MN','NH','VT','MA','RI','CT','NY','NJ','PA','MD','OH','VA','WV','NC','SC','GA','FL','US'])

# Apply filter to census_df
census_df = census_df[df_filter]
census_df.head(20)
# Out:
#    StateCodes           State  Region  Division  Coast  Great Lakes  \
# 6          CT     Connecticut     1.0       1.0    1.0          0.0
# 8          FL         Florida     3.0       5.0    1.0          0.0
# 9          GA         Georgia     3.0       5.0    1.0          0.0
# 19         MD        Maryland     3.0       5.0    1.0          0.0
# 20         MA   Massachusetts     1.0       1.0    1.0          0.0
# 22         MN       Minnesota     2.0       4.0    0.0          1.0
# 28         NH   New Hampshire     1.0       1.0    1.0          0.0
# 29         NJ      New Jersey     1.0       2.0    1.0          0.0
# 31         NY        New York     1.0       2.0    1.0          1.0
# 32         NC  North Carolina     3.0       5.0    1.0          0.0
# 34         OH            Ohio     2.0       3.0    0.0          1.0
# 37         PA    Pennsylvania     1.0       2.0    0.0          1.0
# 38         RI    Rhode Island     1.0       1.0    1.0          0.0
# ...

# %%
# Create function for filtering columns
base_strings = ['TotalP','CoalP','GeoP','HydroP','ElecPrice','NatGasPrice','LPGPrice']

def select_columns(base_string,columns):
    for year in range(2010,2015):
        columns.append(base_string + str(year))
    return columns

columns2 = []
for base_string in base_strings:
    select_columns(base_string,columns2)

print(columns2)
# Out:
# ['TotalP2010', 'TotalP2011', 'TotalP2012', 'TotalP2013', 'TotalP2014', 'CoalP2010', 'CoalP2011', 'CoalP2012', 'CoalP2013', 'CoalP2014', 'GeoP2010', 'GeoP2011', 'GeoP2012', 'GeoP2013', 'GeoP2014', 'HydroP2010', 'HydroP2011', 'HydroP2012', 'HydroP2013', 'HydroP2014', 'ElecPrice2010', 'ElecPrice2011', 'ElecPrice2012', 'ElecPrice2013', 'ElecPrice2014', 'NatGasPrice2010', 'NatGasPrice2011', 'NatGasPrice2012', 'NatGasPrice2013', 'NatGasPrice2014', 'LPGPrice2010', 'LPGPrice2011', 'LPGPrice2012', 'LPGPrice2013', 'LPGPrice2014']

# %%
# Columns for df
final_columns = ['StateCodes', 'Region', 'Division'] + columns2
df = census_df[final_columns]
df
# Out:
#    StateCodes  Region  Division  TotalP2010  TotalP2011  TotalP2012  \
# 6          CT     1.0       1.0      203188      195792      205073
# 8          FL     3.0       5.0      510201      500907      442188
# 9          GA     3.0       5.0      561796      549483      555238
# 19         MD     3.0       5.0      250812      272882      245197
# 20         MA     1.0       1.0      108868      103058      110384
# 22         MN     2.0       4.0      429062      425422      417674
# 28         NH     1.0       1.0      156829      131919      129929
# 29         NJ     1.0       2.0      376845      390931      393682
# 31         NY     1.0       2.0      836703      879395      817908
# 32         NC     3.0       5.0      576162      572796      560887
# 34         OH     2.0       3.0     1032440     1067943     1067944
# 37         PA     1.0       2.0     3064745     3870671     4730336
# 38         RI     1.0       1.0        3399        3419        2822
# ...

# %%
# Export cleaned dataframe
df.to_csv('census_data.csv')
